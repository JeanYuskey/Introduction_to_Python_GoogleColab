# %%
def aaa():
  global x
  print(x)

def bbb():
  x = 45
  print(x)

# %%
x=5
def func():
  #global x 
  print(x)
  # x=6


func()
print(x)
# Out:
# 5
# 5

# %% [markdown]
# ```text
#
# funcao incr(n:inteiro):inteiro
# inicio
# 	se n=5 entao
# 		retorne 1
# 	senao
# 		retorne n+1
# 	fimse
# fimfuncao

# %%
def incr(n):
  if n==5:
    return 1
  else:
    return n+1:

# %% [markdown]
# ```text
# procedimento insere(nome)
# inicio
# 	se incr(fim)=ini entao
# 		escreva("Fila Cheia")
# 	senao
# 		novo<-incr(fim)
# 		v[novo]<-nome
# 		fim<-novo
# 		se ini=0 entao
# 				ini=fim
# 		fimse
# 	fimse
# fimprocedimento

# %%
def insere(nome):
  if incr(fim) == ini:
    print('Fila cheia')
  else:
    novo = incr(fim)
    v[novo] = nome
    fim = novo
    if ini == 0:
      ini = fim

# %% [markdown]
# ```text
#
# funcao chama():cadeia
# inicio
# 			nome<-v[ini]
# 			se ini=fim entao
# 				escreva("Fila vazia")
# 				ini<-0
# 				fim<-0
# 			senao
# 				ini<-incr(ini)
# 			fimse
# 		  retorne nome
# fimfuncao

# %%
def chama():
  nome = v[ini]
  if ini == fim:
    print('Fila vazia')
    ini = 0
    fim = 0
  else:
    ini = incr(ini)
  return nome

# %% [markdown]
# ```text
#
# inicio
# 	ini<-0
# 	fim<-0
# 	repita
# 		escreva("1-insere")
# 		escreva("2- Chama")
# 		escreva("3-sair")
# 		leia (opcao)
# 		escolha (opcao)
# 		caso 1
# 			leia(nome)
# 			insere(nome)
# 		caso 2
# 			escreva(chama())
# 		fimescolha
# 	ate opcao=3
# fim algoritmo

# %%
ini = 0
fim = 0
while True:
  print('1-Insere')
  print("2-Chama")
  print('3-Sair')
  opcao = int(input('Coloque a opção desejada: '))
  if opcao == 1:
    nome = input('Insira o seu nome: ')
    insere(nome)
  elif opcao == 2:
    print('Chama: ')
  else:
    break
# Out:
# 1-Insere
# 2-Chama
# 3-Sair
# Coloque a opção desejada: 2

# %%
v=['','','','',''] #global v
def incr(n):
  if n==5:
    return 1
  else:
    return n+1

def insere(nome):
  if incr(fim) == ini:
    print('Fila cheia')
  else:
    novo = incr(fim)
    v[novo] = nome
    fim = novo
    if ini == -1:
      ini =+ fim
    print(ini)

def chama():
    global ini 
    global fim
    nome = v[ini]
    if ini == fim:
     print('Fila vazia')
     ini = -1
     fim = -1
    else:
     ini = incr(ini)
     return nome

while True:
  print('')
  print('1-Insere')
  print("2-Chama")
  print('3-Sair')
  opcao=int(input('Entre com a opção: '))
  if opcao == 1:
    nome = input('Nome: ')
    insere(nome)
  elif opcao == 2:
    print('Chama: ')
  else:
    break
# Out:
# 1-Insere
# 2-Chama
# 3-Sair
# Entre com a opção: 2
# Chama:
#
# 1-Insere
# 2-Chama
# 3-Sair
# Entre com a opção: 1
# Nome: ko
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-32-2db492b22ba1> in <module>
#      37   if opcao == 1:
#      38     nome = input('Nome: ')
# ---> 39     insere(nome)
#      40   elif opcao == 2:
#      41     print('Chama: ')
#
# <ipython-input-32-2db492b22ba1> in insere(nome)
#       7
#       8 def insere(nome):
# ----> 9   if incr(fim) == ini:
#      10     print('Fila cheia')
#      11   else:
#
# UnboundLocalError: local variable 'fim' referenced before assignment

# %%
v=['','','','',''] #global v
def incr(n):
  if n==4:
    return 0
  else:
    return n+1

def  insere(nome):
  global ini
  global fim
  global v
  if incr(fim) == ini:
    print('\n\nFila cheia\n\n')
  else:
    novo = incr(fim)
    v[novo] = nome
    fim = novo
  if ini == -1:
    ini = fim

def chama():
  global ini
  global fim
  print(ini)
  nome = v[ini]
  if ini==fim:
    print('\n\nFila vazia\n\n')
    ini = -1
    fim = -1
  else:
    ini = incr(ini)
  return nome

def imprime():
  i = ini
  while i !=incr(fim):
    print('\n {0}'. format(v[i]))
    i = incr(i)

ini = -1
fim = -1
while True:
  print('')
  print('1-Insere')
  print("2-Chama")
  print('3-Sair')
  opcao=int(input('Entre com a opção: '))
  if opcao == 1:
    nome = input('Nome: ')
    insere(nome)
  elif opcao == 2:
    print(chama())
  elif opcao == 3:
    break
# Out:
# 1-Insere
# 2-Chama
# 3-Sair
#
# 1-Insere
# 2-Chama
# 3-Sair
#
# 1-Insere
# 2-Chama
# 3-Sair
#
# 1-Insere
# 2-Chama
# 3-Sair
#
# 1-Insere
# 2-Chama
# 3-Sair
#
# 1-Insere
# 2-Chama
# 3-Sair
#
#
# Fila cheia
#
#
#
# 1-Insere
# 2-Chama
# 3-Sair
# 0
# a
#
# 1-Insere
# 2-Chama
# 3-Sair
#
# 1-Insere
# 2-Chama
# 3-Sair
# 1
# b
#
# 1-Insere
# 2-Chama
# 3-Sair

# %%
v = []
def insere(nome):
  global v
  v.append(nome)

def chama():
  if len(v) == 0:
    print('Fila vazia')
    nome = ''
  else:
    nome = v.pop(0)
    return nome

def imprime():
  for i in v:
    print(i)

ini = -1
fim = -1
while True:
  print('')
  print('1-Insere')
  print("2-Chama")
  print('3-Sair')
  opcao=int(input('Entre com a opção: '))
  if opcao == 1:
    nome = input('Nome: ')
    insere(nome)
  elif opcao == 2:
    print(chama())
  elif opcao == 3:
    break
