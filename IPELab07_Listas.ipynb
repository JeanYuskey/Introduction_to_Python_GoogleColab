# %% [markdown]
# Introdução
#
# ■	A forma como os dados são organizados tem um impacto significativo sobre a eficácia com que podem ser usados. Uma das maneiras mais óbvias e úteis de organizar os dados é como uma lista.
#
# ■	Nós usamos listas no nosso dia-a-dia, fazemos listas de compras, listas de tarefas, listas de convidados.
#
# ■	Listas também ocorrem na natureza. Nosso DNA é essencialmente uma longa lista de moléculas na forma de uma dupla hélice, encontrada no núcleo de todas as células humanas e todos os organismos vivos. Sua finalidade também é armazenar informações - especificamente, as instruções usadas para construir todas as outras células do corpo - que chamamos de genes. Dados os 2,85 bilhões de nucleotídeos que compõem o genoma humano, determinar seu sequenciamento (e, assim, entender nossa composição genética) é fundamentalmente um problema computacional.
#
# ■	Veremos o uso de listas na programação. O conceito de uma lista é semelhante à nossa noção cotidiana de uma lista. Nós lemos (acesso) itens em nossa lista de tarefas, adicionamos itens, cruzamos (deletamos) itens e assim por diante.

# %% [markdown]
# O que é uma Lista?
#
# ■	Uma lista é uma estrutura de dados linear que mantém a posição dos seus elementos em uma ordem linear. Ou seja, tem o primeiro elemento, o segundo elemento e assim por diante.
#
# ■	Abaixo nós temos um exemplo de uma lista de compras. Note que o primeiro elemento da lista é o Cereal, o segundo é o Leite, o terceiro é a Banana etc.

# %% [markdown]
# #Operações em uma lista

# %% [markdown]
# ##inicialização

# %%
lst = [1, 10, 3]
lista_compras = ['cereal', 'leite', 'banana', 'maçã', 'iogurte']
lista_vazia=[]

# %%
print(lst)

# %%
print(lista_compras)

# %%
print(lista_vazia)

# %% [markdown]
# ##A função list
# * É útil pois uma lista pode ser modificada, mas uma string

# %%
lista = list('alo')
print(lista)
# Out:
# ['a', 'l', 'o']

# %% [markdown]
# ##recuperar (retrieve)
# * Para recuperar (retrieve) elementos nós acessamos a lista através do seu indice, que é colocado entre colchetes logo após o nome da variável.

# %%
print('Elemento na posição de índice 1:' , lista_compras[3])

# %% [markdown]
# A contagem dos índices em uma Hsta em Python in icia-se em O (zero), e não em 1. Assim, se um1a lista possui 5 itens, o primeiro elemento é acessado utilizando o índice O, o último elemento é acessado utilizando o 1índice 4, e não há elemento co1m índice 5.

# %%
print ( 'Primeiro item:' , lista_compras[ 0])
print ( 'último item:' , lista_compras[ 4])
# Out:
# Primeiro item: cereal
# último item: iogurte

# %%
print ( 'último item:' , lista_compras[ len(lista_compras)-1])
# Out:
# último item: iogurte

# %% [markdown]
# Mostrar o primeiro e o último dígito das lista lst, lista_vazia, lista

# %% [markdown]
# ##substituir (replace)
# deve-se fazer a atribu ição de um novo valor para uma posição
# específica da lista.

# %%
lista_compras = [ 'cereal' , 'leite' , 'banana' , 'maçã' , 'iogurte' ]
print ( 'Antes: ' , lista_compras)
lista_compras[3] = 'mamão'
print ( 'Depois: ' , lista_compras)

# %% [markdown]
# ##inserir (insert)
# um elemento é realizada utilizando o método insert da lista. Para executá-lo deve-se fazer a chamada utilizando a notação do ponto. Para isso, escreve-se:
# * nome da variável que acessa a lista seguido por um ponto (.);
# * nome do método (insert);
# * entre parênteses, o número do índice da posição onde deve ser rea lizada a inserção e o valor a ser inserido.

# %%
lista_compras.insert(4, 'melão' )
print('Depois:' , lista_compras)

# %% [markdown]
# ##remover (remove)
# * um elemento, deve-se utilizar a sentença del seguida do nome da variável e o índice do elemento que será removido.

# %%
lista_compras = [ 'cereal' , 'leite' , 'banana' , 'mamão' , 'melão' , 'iogurte' ]
print ( 'Antes:' , lista_compras)
del lista_compras[ 1 ]
print ( 'Depois: ' , lista_compras)

# %% [markdown]
# ##acrescentar (append)
# * um elemento no final da lista é feita utilizando o método append, informando qual o elemento que deve ser adicionado.

# %%
print ( 'Antes: ' , lista_compras)
lista_compras.append( 'mel' )
print ( 'Depois: ' , lista_compras)

# %% [markdown]
# ## reverse
# * inverte a posição de todos os elementos

# %%
print ( 'Antes: ' , lista_compras)
lista_compras.reverse()
print ( 'Depois:', lista_compras)

# %% [markdown]
# ##ordenar sort

# %%
lista = [9,8,7,1,4,2]
lista.sort()
print(lista)

# %% [markdown]
# Inversão

# %%
lista = [9,8,7,1,4,2]
lista.sort(reverse=True)
print(lista)

# %% [markdown]
# ## remove 2  (pop)
# Remove da lista o elemento na posição índice e o retorna
# Se índice não for mencionado, é assumido o último

# %%
lista = [1,2,3,4]
print( lista.pop())   
print(lista) 
print(lista.pop(1))   
lista
# Out:
# 4
# [1, 2, 3]
# 2
# [1, 3]

# %% [markdown]
# ##juntar (join)
# Ele vai unir cada elemento da lista, colocando uma string entre aos elementos.

# %%
lista = ['a','b','a','c','a','x','i']
fruta=''.join(lista)
fruta

# %% [markdown]
# #Exercício 1
# Quais será o resultado apresentado ao executar as seguintes linhas em um interpretador Python?
#
# $lst = [10, 20, 30]$
#
# $lst[0]$
#
# $lst[0] = 5$
#
# $del\ lst[2]$
#
# $lst.insert(l,15)$
#
# $lst.append(40)$

# %% [markdown]
# Qual será a faixa dos valores dos índices para a lista $lst$?

# %%
#mostre o índice do primeiro elemento

# %%
#mostre como obter índice do último elemento

# %% [markdown]
# Qual será o resultado se inserirmos na lista abaixo o valor 50 na posição de índice 2?
#
#  índice |	elemento
#  --|--
#  0 | 35
# 1 |15
# 2 |45
# 3 |28

# %%
#demonstre efetuando as operações

# %% [markdown]
# #Tuplas
# * Tuplas são sequências de valores, da mesma forma que  listas
# * Mas, existem diferenças...
# ** Os valores de uma tupla, ao contrário de uma lista, são imutáveis
# ** Tuplas usam parênteses enquanto listas usam colchetes

# %%
lista=[1,2,3,4]
tupla=(1,2,3,4)

# %% [markdown]
# * Tupla vazia

# %%
tupla=()

# %% [markdown]
# * Tupla com um único elemento (note a necessidade da  vírgula, mesmo sendo um único elemento)

# %%
tupla=(1,)

# %% [markdown]
# ##operações

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Fatias (slices)

# %% [markdown]
# Sintaxe (para urna sequência acessada pela variável s, posições $indice 1$ até $indice 2$):

# %%
lista = [1, 'a', 2+3j, ['ab', 'CD']]

# %%
lista [0]
lista

# %%
lista [2] 
lista

# %%
lista [3]  
lista

# %%
lista [-1]   
lista

# %%
lista [0] = 2
lista

# %% [markdown]
# Trabalhando com Slices

# %%
lista = [1, 'a', 2+3j, ['ab', 'CD']]
lista [1:]

# %%
lista [:1]

# %%
lista [1:2]

# %%
lista [0:-1]

# %% [markdown]
# ##Incrementos em Fatias
# É possível usar um terceiro número na notação de  fatias designando o incremento
# * Default é 1 , ou seja, toma os elementos de um em um  do menor para o maior índice
# * Pode­se usar qualquer número inteiro diferente de 0
# ** $a[0:10:2]$ retorna uma lista com os 10 primeiros elementos  de a tomados de 2 em 2 (5 elementos, no máximo)
# ** $a[5:0:-1]$ retorna uma lista com os 5 primeiros elementos  de a tomados da esquerda para a direita
#
# Obs.: Esta notação só existe nas versões de Python a  partir da 2.3

# %%
a = ['a', 2, 3, 'd', 'x']
a [:3:2]

# %% [markdown]
# O que irá acontecer?

# %%
a[::-1]

# %% [markdown]
# Se um incremento de fatia é diferente de 1, uma  atribuição à fatia deve ter o mesmo número de  elementos:

# %%
lst = [1,2,3,4,5]
lst [0::2] = ['x','y','z']
lst
# Out:
# ['x', 2, 'y', 4, 'z']

# %%
lst [0::2] = [6,7]

# %% [markdown]
# #Exercício

# %% [markdown]
# Pilha:
# * O último que entra na sequência é o primeiro a sair;
# * Conhecido como (Last In First Out (LIFO).
# Uma pilha é. portanto, uma lista linear em que as operações são sempre realizadas pelo topo

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Fila:

# %% [markdown]
# Conceito:
# * O primeiro que entra é o primeiro que sai
# * Conhecido como FIFO – First In First Out
# * A ideia fundamental da fila é que só podemos inserir um novo elemento no final da fila e só podemos retirar o elemento que está no início da fila

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Insere E
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Retira
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Monte as funções
# * PushPilha() para insersão em pilha
# * PopPilha() para remoção em pilha
# * QueueFila() para insersão em fila
# * Dequeue() para remoção em fila
#
# em uma fila F e pilha P

# %%
PushPilha('abobora')
PushPilha('cenoura')
PushPilha('Laranja')
print('desempilhado ',PopPilha())
print('desempilhado ',PopPilha())
print('desempilhado ',PopPilha())
print('desempilhado ',PopPilha())
QueueFila('Manuel')
QueueFila('Joaquim')
QueueFila('Nuno')
QueueFila('Maria')
print('saindo da fila ',DequeueFila())
print('saindo da fila ',DequeueFila())
QueueFila('Isabel')
print('estado atual',f)
print('saindo da fila ',DequeueFila())
print('saindo da fila ',DequeueFila())
print('saindo da fila ',DequeueFila())
print('saindo da fila ',DequeueFila())
# Out:
# empilhado  abobora
# empilhado  cenoura
# empilhado  Laranja
# desempilhado  Laranja
# desempilhado  cenoura
# desempilhado  abobora
# desempilhado  pilha vazia
# saindo da fila  Manuel
# saindo da fila  Joaquim
# estado atual ['Isabel', 'Maria', 'Nuno']
# saindo da fila  Nuno
# saindo da fila  Maria
# saindo da fila  Isabel
# saindo da fila  Fila vazia
