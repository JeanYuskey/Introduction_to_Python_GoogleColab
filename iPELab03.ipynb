# %% [markdown]
# #Estrutura Condicional
#
# * Trata-se de uma estrutura responsável pelo desvio na seqüência de execução das instruções em um programa
# * Executam o desvio da execução do programa em conformidade com o resultado lógico de uma expressão relacional ou lógica (CONDIÇÃO).

# %% [markdown]
# ##Decisão
#
# Mecanismos de decisão:
#
# `if ...`
# > * Executa algo somente quando uma condição é verdadeira
# `if... else`
# > * Bifurca a execução do código em função de uma condição
# `if... elif...`
# > * Executa apenas o bloco em que a condição é verdadeira

# %% [markdown]
# ##Decisão do tipo if...
# * Executa o bloco de instruções somente se a condição for  verdadeira
# * A condição é uma expressão booleana que pode fazer  uso de quaisquer operadores
# * O bloco de instruções é delimitado por indentação

# %% [markdown]
# Exemplo301: Programa para informar quando um número inteiro é par:

# %% [markdown]
# ![Image 095 2022 12.png](data:image/png;base64,...)

# %%
numero = int(input("Entre com um número: "))  
resto=numero % 2
if resto == 0:
    print("O número é par.")
# Out:
# O número é par.

# %% [markdown]
# ##Decisão do tipo if... else
# * Executa um ou o outro bloco de instruções em função da  condição ser verdadeira ou falsa
# * Valem as mesmas regras para `if...`
# * Qualquer combinação de instrução individual ou em  bloco é aceita no corpo do `if` ou do `else`
# * Podem ser aninhados com outras estruturas

# %% [markdown]
# Exemplo302: Programa para informar se um número é par ou impar:

# %% [markdown]
# ![Image 096 2022 12.png](data:image/png;base64,...)

# %%
numero = int(input("Entre com um número: "))  
if numero % 2 == 0:
    print("O número é par.")
else:
    print("O número é impar.")
# Out:
# Entre com um número: 3
# O número é impar.

# %% [markdown]
# ##Decisão do tipo if... elif...
#
# * Apenas o bloco no qual a condição é  verdadeira é executado
# * É possível colocar tantos _**elif**_ quantos  forem necessários
# * Qualquer combinação de instrução  individual ou em bloco é aceita no corpo  do **_`if`_** ou do _**`elif`**_
# * É possível adicionar um _**`else`**_ ao final de  tudo
# > Nesse caso, se nenhuma condição for  verdadeira, o bloco do else será executado

# %% [markdown]
# 6. Saúde para dar uma indicação sobre a condição de peso de uma pessoa adulta. A fórmula é
#
# $IMC = peso / ( altura )^2$
#
# Elabore um algoritmo que leia o peso e a altura de um adulto e mostre sua condição de acordo com a tabela abaixo.
# IMC em adultos
# *	Condição Abaixo de 18,5 Abaixo do peso
# *	Entre 18,5 e 25 Peso normal
# *	Entre 25 e 30 Acima do peso
# *	Acima de 30 obeso

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
peso = float(input("Digite seu peso(kg): "))
alt = float(input("Dgite sua altura (m): "))
imc = peso/alt**2
if imc < 18.5:
  print("IMC: {0}; Abaixo do peso".format(imc))
if imc >= 18.5 and imc < 25:
  print("IMC: {0}; Peso normal".format (imc))
if imc >= 25 and imc < 30:
  print("IMC: {0}; Acima do peso".format (imc))
if imc >= 30:
  print("IMC: {0}; Obeso".format (imc))
# Out:
# Digite seu peso(kg): 68
# Dgite sua altura (m): 1.85
# IMC: 19.86851716581446; Peso normal

# %%
h=float(input("entre com a altura"))
peso=float(input("entre com o peso"))
imc=peso/(h*h)
print(imc)
if imc<18.5:
  print("abaixo do peso")
elif imc<25:
  print("normal")
elif imc<30:
  print("acima do peso")
else:
  print("Obeso")
# Out:
# entre com a altura68
# entre com o peso1.85
# 0.0004000865051903114
# abaixo do peso

# %% [markdown]
# Exercício 3.1

# %% [markdown]
# Entre com dois números e mostre o maior.

# %% [markdown]
# ![Image 097 2022 12.png](data:image/png;base64,...)

# %%
n1=int(input("entre com o primeiro número: "))
n2=int(input("entre com o segundo número: "))
if n1>n2:
  print(n1)
else:
  print(n2)
# Out:
# entre com o primeiro número: 1
# entre com o segundo número: 2
# 2

# %% [markdown]
# Exercício 3.2

# %% [markdown]
# Entre com três números e mostre o maior

# %% [markdown]
# ![Image 098 2022 12.png](data:image/png;base64,...)

# %%
n1=int(input("Entre com o primeiro número: "))
n2=int(input("Entre com o segundo número: "))
n3=int(input("Entre com o terceiro número: "))
if n1>n2:
  if n2>n3:
    print(n1)
  elif n1>n3:
    print(n3)
else:
  if n2>n3:
    print(n2)
  else:
    print(n3)
# Out:
# Entre com o primeiro número: 15145
# Entre com o segundo número: 654561
# Entre com o terceiro número: 44
# 654561

# %% [markdown]
# ![Image 100 2022 12.png](data:image/png;base64,...)

# %%
n1=int(input("Entre com o primeiro número: "))
n2=int(input("Entre com o segundo número: "))
n3=int(input("Entre com o terceiro número: "))
if (n1>n2) and (n1>n3):
  print(n1)
if (n2>n1) and (n2>n3):
  print(n2)
if (n3>n1) and (n3>n2):
  print(n3)
# Out:
# Entre com o primeiro número: 5
# Entre com o segundo número: 10
# Entre com o terceiro número: 15
# 15

# %% [markdown]
# ![Image 101 2022 12.png](data:image/png;base64,...)

# %%
n1=int(input('entre com o primeiro número: '))
n2=int(input('entre com o segundo número: '))
n3=int(input('entre com o segundo número: '))
omaior=n1
if omaior<n2:
  omaior=n2
if omaior<n3:
  omaior=n3
print(omaior)
# Out:
# entre com o primeiro número: 1
# entre com o segundo número: 2
# entre com o segundo número: 3
# 3

# %%
n1=int(input('entre com o primeiro número: '))
n2=int(input('entre com o segundo número: '))
n3=int(input('entre com o segundo número: '))
if n1>n2 and n1>n3:
  print("Maior: ", n1)
if n2>n1 and n2 >n3:
  print("Maior: ", n2)
if n3>n1 and n3>n2:
  print("Maior: ", n3)
# Out:
# entre com o primeiro número: 1
# entre com o segundo número: 2
# entre com o segundo número: 1
# Maior:  2

# %%
n1=int(input('entre com o primeiro número: '))
n2=int(input('entre com o segundo número: '))
n3=int(input('entre com o segundo número: '))
if n1>=n2 and n1>=n3:
  print("Maior: ", n1)
elif n2>=n1 and n2 >=n3:
  print("Maior: ", n2)
else: 
  print("Maior: ", n3)
if n1==n2 or n2==n3 or n1==n3:
  print('Há números iguais')
# Out:
# entre com o primeiro número: 1
# entre com o segundo número: 2
# entre com o segundo número: 1
# Maior:  2
# Há números iguais

# %% [markdown]
# 2
# Exercício 3.3

# %% [markdown]
# Efetuar a leitura de 3 número e apresentar em ordem crescente

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n1=int(input('entre com o primeiro número: '))
n2=int(input('entre com o segundo número: '))
n3=int(input('entre com o terceiro número: '))
if n1>n2:
  if n2>n3:
    print(n3,n2,n1)
  elif n1>n3:
    print(n2,n3,n1)
  else:
    print(n2,n1,n3)
elif n1>n3:
  print(n3,n1,n2)
# Out:
# entre com o primeiro número: 1
# entre com o segundo número: 2
# entre com o terceiro número: 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n1=int(input('Entre com o primeiro número: '))
n2=int(input('Entre com o segundo número: '))
n3=int(input('Entre com o terceiro número: '))
if n1>n2:
  aux=n1
  n1=n2
  n2=aux
if n2>n3:
  aux=n2
  n2=n3
  n3=aux
if n1>n2:
  aux=n1
  n1=n2
  n2=aux
print(n1,n2,n3)
# Out:
# Entre com o primeiro número: 12
# Entre com o segundo número: 6
# Entre com o terceiro número: 91
# 6 12 91

# %% [markdown]
# Exercício 3.4

# %% [markdown]
# Entre com 3 números e diga se tem um número impar

# %% [markdown]
# ![Image 102 2022 12.png](data:image/png;base64,...)

# %%
n1=int(input('Entre com o primeiro número: '))
n2=int(input('Entre com o segundo número: '))
n3=int(input('Entre com o terceiro número: '))
flag = False
if (n1 % 2) == 1:
  flag=True
if (n2 % 2) == 1:
  flag=True
if (n3 % 2) == 1:
  flag=True
if flag:
  print('Tem impar')
else:
  print('Não tem impar')
# Out:
# Entre com o primeiro número: 2
# Entre com o segundo número: 4
# Entre com o terceiro número: 5
# Tem impar

# %% [markdown]
# Exercício 3.5

# %% [markdown]
# Tendo como dados de entrada a altura e o sexo de uma pessoa, construa um algoritmo que calcule seu peso ideal, utilizando as seguintes fórmulas:
#
# * para homens: $(72.7 * h) – 58$;
# * para mulheres: $(62.1 * h) – 44.7$.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
h=float(input('Entre com a altura: '))
sexo=str(input('Qual o sexo (m/f)? '))
if sexo == 'm':
  peso = (72.7*h)-58
  print('Peso ideal: {0}'.format(peso))
else:
  peso = (62.1*h)-44.7
  print('Peso ideal: {0}'.format(peso))
# Out:
# Entre com a altura: 1.78
# Qual o sexo (m/f)? m
# Peso ideal: 71.406

# %% [markdown]
# Exercício 3.6

# %% [markdown]
# Efetuar a leitura de 1 número e informar se ele é divisível por 2 e 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n1=int(input('Entre com o número: '))
if n1 % 2 == 0 and n1 % 3 == 0:
  print(" é divisível por 2 e 3")
# Out:
# Entre com o número: 6
#  é divisível por 2 e 3

# %% [markdown]
# Exercício 3.7

# %% [markdown]
# Faça um programa para calcular se um ano é bissexto (divisível por 4)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n1=int (input(" Entre com o ano: "))
if n1 % 4 == 0:
  print('é Bissexto')
# Out:
#  Entre com o ano: 2020
# é Bissexto

# %% [markdown]
# Completando

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n1=int (input(" Entre com o ano: "))
if n1 % 400 == 0:
  print('é Bissexto')
elif n1 % 100 == 0:
  print('não é Bissexto')
elif n1 % 4 == 0:
  print('é Bissexto')
else:
  print('não é Bissexto')
# Out:
#  Entre com o ano: 2022
# não é Bissexto

# %% [markdown]
# Exercício 3.7

# %% [markdown]
# Escreva um programa para classificar um triangulo de lados de comprimentos dados em escaleno (os três lados de comprimentos diferentes), isósceles (dois lados de comprimentos iguais) ou equilátero (os tres lados de comprimentos iguais).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a=int(input('Entre com o lado 1: '))
b=int(input('Entre com o lado 2: '))
c=int(input('Entre com o lado 3: '))
if a >= b+c or b >= a+c or c >= a+b:
  print('Não forma um triângulo')
elif a==b and b==c:
  print('Triângulo equilátero')
elif a==b or b==c or a==c:
  print('Triângulo isósceles')
else:
  print('triângulo escaleno')
# Out:
# Entre com o lado 1: 11
# Entre com o lado 2: 12
# Entre com o lado 3: 13
# triângulo escaleno

# %% [markdown]
# Exercício 3.8

# %% [markdown]
# Escreva um algoritmo que leia o número de identificação, as 3 notas obtidas por um aluno nas 3 verificações e a média dos exercícios (ME) que fazem parte da avaliação, e calcule a média de aproveitamento (MA), usando a fórmula:
#
# **MA <- (nota1 + nota 2 * 2 + nota 3 * 3 + ME)/7**
#
# A atribuição dos conceitos obedece a tabela abaixo. O algoritmo deve escrever o número do aluno, suas notas, a média dos exercícios, a média de aproveitamento, o conceito correspondente e a mensagem 'Aprovado' se o conceito for A, B ou C, e 'Reprovado' se o conceito for D ou E.
#
# Média de aproveitamento Conceito
#
# * $>=$ 9 A
# * $>=$ 7,5 e < 9 B
# * $>=$ 6 e < 7,5 C
# * $>=$ 4 e < 6 D
# * $<$ 4 E

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ident = input('Digite seu n° de identificação: ')
n1 = float(input('Digite sua nota I: '))
n2 = float(input('Digite sua nota II: '))
n3 = float(input('Digite sua nota III: '))
ME = (n1 + n2 + n3)/3
MA = (n1 + n2*2 + n3*3 + ME)/7
if (MA >= 9):
  print('A | Aprovado')
elif (MA < 9 and MA >= 7.5):
  print('B | Aprovado')
elif (MA < 7.5 and MA >=6):
  print('C | Aprovado')
elif (MA < 6 and MA >=4):
  print('D | Reprovado')
elif (MA < 4):
  print('F | Reprovado')
# Out:
# Digite seu n° de identificação: N000635
# Digite sua nota I: 10
# Digite sua nota II: 9
# Digite sua nota III: 8
# B | Aprovado

# %%
n1 = float(input('Entre com a n1: '))
n2 = float(input('Entre com a n2: '))
n3 = float(input('Entre com a n3: '))
media = ((n1+n2)*2+n3*2)/7
if media >= 9:
  print('A - Aprovado')
elif media >= 7.5:
  print('B - Aprovado')
elif media >= 6:
  print(' C - Aprovado')
elif (MA < 6 and MA >=4):
  print('D | Reprovado')
elif (MA < 4):
  print('F | Reprovado')
# Out:
# Entre com a n1: 2
# Entre com a n2: 5
# Entre com a n3: 3

# %% [markdown]
# Exercício 3.9

# %% [markdown]
# Elabore um algoritmo que calcule o que deve ser pago por um produto, considerando o preço normal de etiqueta e a escolha da condição de pagamento. Utilize os códigos da tabela a seguir para ler qual a condição de pagamento escolhida e efetuar o cálculo adequado.
#
# Código Condição de pagamento
#
# 1. À vista em dinheiro ou cheque, recebe 10% de desconto
# 1. À vista no cartão de crédito, recebe 15% de desconto
# 1. Em duas vezes, preço normal de etiqueta sem juros
# 1. Em duas vezes, preço normal de etiqueta mais juros de 10%

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
precoetiqueta = float(input('Entre com o preço'))
opcao = int(input('Entre com a opção de pagamento: '))
def valor(opcao):
  match opcao:
    case 1:
      pagto = precoetiqueta* 0.9
      print('Total: ', pagto)
    case 2:
      pagto = precoetiqueta* 0.85
      print('Total: ', pagto)
    case 3:
      pagto = precoetiqueta/2
      print('Pagamento 1: ', pagto)
      print('Pagamento 2: ', pagto)
      print('Total: ', precoetiqueta)
    case 4:
      pagto = (precoetiqueta*1.1)/2
      print('Pagamento 1: ', pagto)
      print('pagamento 2: ', pagto)
      print('Total: ',pagto*2)
# Out:
#   File "<ipython-input-27-ac461c0b8b47>", line 4
#     match opcao:
#               ^
# SyntaxError: invalid syntax
