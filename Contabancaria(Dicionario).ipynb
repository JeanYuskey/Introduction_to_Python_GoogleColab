# %% [markdown]
# # Dicionário vazio:
# ```python
# agenda = {}
# ```
# # Chave é separada de seu valor por dois pontos
# ```python
#  agenda = {"Maria":	[99887766, 99887755]}
# ```
# # Cada par chave-valor é separado por vírgula dos pares  seguintes
# ```python
#  agenda = {"Maria": [99887766, 99887755],
# "Pedro": [92345678],	"Joaquim": [99887711,
# 99665533]}
# ```

# %%
l = ['Maria','Pedro','Joaquim'] #lista(entre conchete '[]')
l[0] #índice numérico 'l[0]'
agenda = {"Maria": [99887766, 99887755], "Pedro": [92345678],    "Joaquim": [99887711,99665533]} #dicionário(entre chave '{}')
agenda['Joaquim']
# Out:
# [99887711, 99665533]

# %% [markdown]
#  Acesso a Dados de um Dicionário
# # Acesso é sempre feito pela chave
# ```python
#  agenda = {"Maria": [99887766, 99887755],
# "Pedro": [92345678],	"Joaquim": [99887711,
# 99665533]}
#  telMaria	= agenda["Maria"]
#  telMaria  [99887766,09887755]

# %%
agenda = {"Maria": [99887766, 99887755], "Pedro": [92345678],    "Joaquim": [99887711,99665533]}
telMaria = agenda["Maria"]

# %% [markdown]
#  Usar a chave
# ```python
#  agenda = {"Maria": [99887766, 99887755], "Pedro": [92345678], "Joaquim": [99887711, 99665533]}
#  agenda["Pedro"] = [87654433]
#  agenda
# {"Maria": [99887766, 99887755], "Pedro": [87654433], "Joaquim": [99887711, 99665533]}

# %% [markdown]
# #Acrescentar Novos Valores
# *Basta fazer atribuição a uma chave não existente
# *Vale mesmo quando o dicionário está vazio
# ```python
#  agenda = {}
#  agenda["Teresa"] = [65443322]
#  agenda
# {"Teresa": [65443322]}

# %%
vnome='Manuel'
aluno={} #variável chamado aluno colocado no emndereço 3000
aluno['nome']=vnome
aluno['endereço']='Rua A,1'
aluno['nota 1']=5
aluno['nora 2']=8

classe={}
classe['1abc']=aluno

aluno={} #criado um novo aluno para colocar em outro endereço, tipo endereço 3100
aluno['nome']='Maria'
aluno['endereço']='Rua B,2'
aluno['nota 1']=7
aluno['nora 2']=6
classe['234bx']=aluno

aluno={}
aluno['nome']='Nuno'
aluno['endereço']='Rua C,3'
aluno['nota 1']=8
aluno['nota 2']=4
classe['123ab']=aluno
#classe['1abc']['nota 2']

for i in classe: 
  #print(i) #printa apenas as chaves (i)          1abc 234bx 123ab

  #print(classe[i]) #printar todos os dados de cada aluno            {'nome': 'Manuel', 'endereço': 'Rua A,1', 'nota 1': 5, 'nora 2': 8}{'nome': 'Maria', 'endereço': 'Rua B,2', 'nota 1': 7, 'nora 2': 6}{'nome': 'Nuno', 'endereço': 'Rua C,3', 'nota 1': 8, 'nota 2': 4}
  
  #print(classe[i]['endereço']) # printa apenas os endereços de cada aluno            Rua A,1 Rua B,2 Rua C,3
# Out:
# Rua A,1
# Rua B,2
# Rua C,3

# %% [markdown]
#  #Ordem
# * As chaves dos dicionários não são armazenadas em  nenhuma ordem específica
# ** Na verdade, dicionários são implementados por tabelas de  espalhamento (Hash Tables)
# ** A falta de ordem é proposital
#
# #Dicionários x Listas
# * Diferentemente de listas, atribuir a um elemento de um  dicionário não requer que a posição exista previamente  (isso ocorre porque não se trata de posição, e sim de  valor da chave!)
#
# ```python
# lista = []
# lista[10] = 5	# ERRO!
# dicionario	= {}
# dicionario[10] = 5
# dicionario
# {10: 5}
# ```

# %%
lista = [] #criada uma lista vazia
lista[10] = 5    # ERRO!

dicionario    = {} #não existe index no dicionário
dicionario[10] = 5
dicionario
{10: 5}

# %% [markdown]
# #Variável do tipo dicionários também  armazena endereço de memória
# * Com dicionários, ocorre o mesmo efeito que ocorre com  cópia de listas – o que é copiado é o endereço de  memória, e portanto, alterações nas cópias são refletidas  umas nas outras
# ```python
# d1={"Catarina":5}
# d2=d1
# di["Jonas"]=
# d2
# ```

# %%
#na memória ram, vai armazenar o endereço(byte) e não a informação, ex: d1=1500 d2=d1 d2=1500, concluindo estamos trabalhando sempre na msm memória
d1={'Catarina':5}
print(d1)

d2=d1
print(d2)

d1['Manuel']=8
print(d2)

d1['Joaquim']=7
print(d2)
# Out:
# {'Catarina': 5}
# {'Catarina': 5}
# {'Catarina': 5, 'Manuel': 8}
# {'Catarina': 5, 'Manuel': 8, 'Joaquim': 7}

# %% [markdown]
# #copy()
# * Retorna um outro dicionário com os mesmos pares  chave/conteúdo
# ```python
# d1={"Catarina":5,"Jonas":20}
# d2=d1.copy()    copia e transfere para outro espaço da memória
# d2["Pedro"]=88
# d1["João"]=40
# print(d1)
# print(d2)
# ```
# * Se conteúdo for lista, o que é copiado é apenas a  referência...
#
# ```python
# d1={"Catarina":[1,2],"Jonas":20}
# d2=d1.copy()
# d2["Catarina"]+=88
# d1.pop("Jonas")
# print(d1)
# print(d2)

# %%
#2 endereços diferentes, em que as informações de d1 é copia e transferido para o endereço d2
#quando criado uma lista e dentro uma outra lista(a informação é armazenada em outra parte qualquer da memória),e ao fazer copy(), dentro da memória 1500 terá o endereço 1700 e não a informação

d1={"Catarina":[1,2],"Jonas":20}
d2=d1.copy()
d2["Catarina"]+=[88]
d1.pop("Jonas")
print(d1)
print(d2)
# Out:
# {'Catarina': [1, 2, 88]}
# {'Catarina': [1, 2, 88], 'Jonas': 20}

# %% [markdown]
#  # Funçăo dict()
# * Função dict() pode ser usada para criar dicionários
# * Pode receber dois tipos de parâmetros
# ** Listas de tuplas, sendo que cada tupla contém uma chave e  conteúdo
# ** Sequencias de itens no formato chave=valor
#
#  # dict() com lista de tuplas
# * Cada tupla da lista contém uma chave e conteúdo
#
# ```python
# produtos = dict([(10, 4.5), (20, 5.99)]) #10 é chave e 4.5 é valor
# valorProd	= produtos[10]
# print(valorProd)
# valorProd	= produtos[20]
# print(valorProd)
# ```
#
#
#
#  #dict() com sequencia de itens chave=valor
# * Sequencias de itens no formato chave=valor
# * Nesse caso as chaves precisam ser strings, mas são  escritas sem aspas
#
# ```python
# produtos = dict(prod10=4.5,prod20= 5.99) #semelhante a criação de variáveis, que deve usar string na criação da variável
# valorProd	= produtos["prod10"]
# print(valorProd)
# ```
#
# com chave numerica
#
# ```python
# produtos = dict(10=4.5,20= 5.99)
# ```

# %%
d1 = {"Catarina": 5, "Jonas": 20}
d2 = dict(Catarina=5, Jonas=20) #uso principal do dict é transforma uma lista de variáveis em tuplas
lista=[("Catarina", 5),("Jonas", 20)]
d3=dict(lista)

print(d1)
print(d2)
print(d3)

vChave='RA123'
d4={vChave:56}
vChave='RA123'
print(d4)
# Out:
# {'Catarina': 5, 'Jonas': 20}
# {'Catarina': 5, 'Jonas': 20}
# {'Catarina': 5, 'Jonas': 20}
# {'RA123': 56}

# %% [markdown]
# # get(chave, valor)
# * Obtém o conteúdo associado à chave
# * Se chave não existe, retorna valor
# * Se valor não for especificado, chamadas de get para chaves  inexistentes retornam None
#
# ```python
# notas = {"Joao":[9.0,8.0], "Maria":  [10.0]}
# print(notas.get("Maria"))
# print(notas.get("Pedro"))  #None
# print( notas.get("Carlos","N/A")) # N/A
# ```

# %%
notas = {"Joao":[9.0,8.0], "Maria":  [10.0]}
print(notas['Maria'])
print(notas.get("Maria"))

#print(notas['Pedro])

print(notas.get("Pedro"))  #None
print( notas.get("Carlos","Não achei")) # N/A

#notas.get("chave", "texto se não achar")
# Out:
# [10.0]
# [10.0]
# None
# Não achei

# %% [markdown]
# # in
# * Retorna True se chave pertence ao dicionário e False
# caso contrário
#
# ```python
# notas = {"Joao":[9.0,8.0], "Maria":  [10.0]}
# "Pedro" in notas  #False
# ```

# %%
notas = {"Joao":[9.0,8.0], "Maria":  [10.0]}
"Pedro" in notas  #False
# Out:
# False

# %% [markdown]
# # items()
# * Retorna uma lista com todos os pares chave/conteúdo do  dicionário no formato de tupla
#
# ```python
# notas = { "Joao":[9.0,8.0], "Maria":  [10.0] }
# print( notas.items()) # [("Joao",[9.0,8.0]), ("Maria",[10.0])]
# ```

# %%
notas = { "Joao":[9.0,8.0], "Maria":  [10.0] }
print( notas.items()) # [("Joao",[9.0,8.0]), ("Maria",[10.0])]
# Out:
# dict_items([('Joao', [9.0, 8.0]), ('Maria', [10.0])])

# %% [markdown]
# # keys()
# * Retorna uma lista com todas as chaves do dicionário
#
# ```python
# notas = {"Joao":[9.0,8.0], "Maria":  [10.0]}
# print( notas.keys()) # ["Joao", "Maria"]
# ```

# %%
notas = {"Joao":[9.0,8.0], "Maria":  [10.0]}
print( notas.keys()) # ["Joao", "Maria"]
for i in notas:
  print(i)
# Out:
# dict_keys(['Joao', 'Maria'])
# Joao
# Maria

# %% [markdown]
# # values()
# * Retorna uma lista com todos os valores do dicionário
#
# ```python
# notas = {"Joao":[9.0,8.0],  "Maria":[10.0]}
# print(notas.values()) # [[9.0, 8.0] , [10.0]]
# ```

# %% [markdown]
# # pop(chave)
# Obtém o valor correspondente à chave e remove o par  chave/valor do dicionário
#
# ```python
# notas = {"Joao":[9.0,8.0], "Maria":  [10.0]}
# print( notas.pop("Joao")) # [9.0,8.0]
# print( notas)
# ```

# %%
notas = {"Joao":[9.0,8.0], "Maria":  [10.0]}
print( notas.pop("Joao")) # [9.0,8.0]
print( notas)
# Out:
# [9.0, 8.0]
# {'Maria': [10.0]}

# %% [markdown]
#  # update(dic)
# * Atualiza um dicionário com os elementos de outro
# * Os itens em dic são adicionados um a um ao dicionário  original (que foi usado para chamar a função update)
# * É possível usar a mesma sintaxe da função dict para  especificar dic
#
# ```python
#
# x={"a":1,"b":2,"c":3}
# y={"m":50,"n":60,"c":70}
# x.update(y)
# print(x)
# ```

# %%
x={"a":1,"b":2,"c":3}
y={"m":50,"n":60,"c":70} #c foi atualizado para 70, ocorreu uma consolidação em relação com a anterior
x.update(y)
print(x)
# Out:
# {'a': 1, 'b': 2, 'c': 70, 'm': 50, 'n': 60}

# %% [markdown]
# # Iterando com Dicionários
# * A iteração em elementos de um dicionário é feita a partir  da chave
# * Lembre-se de que com dicionários não temos ordem pré-  definida
# ```python
# notas = {"Joao":[9.0,8.0], "Maria":[10.0]}
# for nome in notas:
#   media = sum(notas[nome])/len(notas[nome])
#   print("A média de ", nome, " é: ", media)
# ```

# %% [markdown]
# Considere a estrutura abaixo

# %% [markdown]
# Ela define o controle das contas correntes de um banco

# %%
conta={}
conta[numero]={"nome":nome,"saldo":saldo,"limite":limite}]

nome=input("Entre com o nome:")
 limite=float(input("Entre com o limite"))
 numero+=1
 conta[numero]={"nome":nome,"saldo":0,"limite":limite}
 mostraconta(numero)

# %% [markdown]
# faça as seguinte funções:
#
# criaconta():inclui uma nova conta lendo o nome e o limite
# ```python
#   nome=input("Entre com o nome:")
#   limite=float(input("Entre com o limite"))
#   numero+=1
#   conta[numero]={"nome":nome,"saldo":0,"limite":limite}
#   mostraconta(numero)
# ```
#
#
# mostraconta(n): mostra a informação da conta n
# ```python
#   if n in conta:
#     print("Conta:",numero)
#     print(conta[n])
# ```

# %% [markdown]
# deposita(numero, valor) atualiza o saldo da conta numero com o valor
# ```python
#   conta[numero]['saldo']=conta[numero]['saldo']+valor
# ```
#
# saca(numero,valor) atualiza o saldo da conta numero com o valor
# ```python
#   conta[numero]['saldo']=conta[numero]['saldo']-valor
#
# ```
# * Não permite saldo+Limite negativo
#
# * opcao de zerar o saldo

# %%
def deposita(numero, valor):

# %%
def saca(numero, valor):

# %% [markdown]
# relatorio(): mostra todos os nomes e saldos
#
# menu com
# inclusão deposito saque saldo e relatório

# %%
def  saca(numero, valor):
  global conta
  if numero in conta:
    if valor >= conta[numero]['saldo'] + conta[numero]['limite']:
      conta[numero]['saldo'] = conta[numero]['saldo'] - valor
    else:
      print('Sem fundo suficiente')
      
def relatorio():
  for i in conta:
    mostraconta(i)

def inputNum():
  while True:
    n=int

conta={}
print('Sistema Bancário')
while True:
  print('1-Cria conta')
  print('2-Depósito')
  print('3-Saque')
  print('4-Saldo')
  print('5-Relatório')
  print('0-sai')
  
  print('Entre com a opção: ')
  opcao = inputNum
  if opcao == 1:
    criaconta();
  elif opcao == 2:
    print('Entre com o número da conta: ')
    numero=inputNum()
    valor=float(input('Entre com o Valor: '))
    saca(numero,valor)
  elif opcao == 4:
    relatorio
  elif opcao == 8:
