# %% [markdown]
# # **SEQUÊNCIAS**
#
# Sequências são containers, um tipo de dado que contém outros dados. Existem três tipos básicos de sequência: **list** (lista), **tuple** (tupla) e **range** (objeto de intervalo). Outro tipo de sequência famoso que já vimos são as **strings**, que são sequências de texto.
#
# Sequências podem ser mutáveis ou imutáveis. Sequências imutáveis não podem ter seus valores modificados. Tuplas, strings e ranges são sequências imutáveis, enquanto listas são sequências mutáveis.
#
# **LISTAS**
#
# Uma das principais característica do Python são as listas. Uma Lista é uma sequência de valores onde cada valor é identificado por um índice iniciado por 0.
#
# São similares a strings (coleção de caracteres) exceto pelo fato de que os elementos de uma lista podem ser de qualquer tipo. No Python, listas substituem os arrays (vetores e matrizes).
#
# Sua sintaxe é simples, listas são delimitadas por colchetes e seus elementos separados por vírgula:
#
# **lista1 = [1, 2, 3, 4]**
#
# Listas não precisam necessariamente conter elementos de mesmo tipo; assim, podemos ter listas heterogêneas:
#
# **lista = [1, 2, 'python', 3.5, 'java']**
#
# Se queremos selecionar um elemento específico utilizamos o operador [ ] passando a posição, como se fosse para indicar um caractere de um string:
#
# Se queremos selecionar um elemento específico utilizamos o operador [ ] passando a posição, como se fosse para indicar um caractere de um string:
#
# **lista = [1, 2, 3, 4]**
#
# - lista[0] = 1
#
# - lista[1] = 2
#
# - lista[2] = 3
#
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# **Manipulação de Listas**
#
# Inserção de elementos em uma lista (s indica o nome da lista):
#
# - s.append(x): insere o elemento x ao final da lista s (apenas um elemento);
#
# - s.extend([elementos]): insere o conjunto de elementos indicados ao final da lista s
#
# - s.insert(posição, elementos): insere o conjunto de elementos indicados na posição indicada;
#
# - del(s[x]): remove o elemento de posição x  da lista s; os índices do elementos posteriores são readequados de acordo;
#
# - s.clear(): remove todos os elementos da lista s.
#
# **Exercícios**
#
# 1) Dada a lista = [12, -2, 4, 8, 29, 45, 78, 36, -17, 2, 12, 8, 3, 3, -52] faça um programa que:
#
# a) imprima o maior elemento
#
# b) imprima o menor elemento
#
# c) imprima os números pares
#
# d) imprima o número de ocorrências do primeiro elemento da lista
#
# e) imprima a média dos elementos
#
# f) imprima a soma dos elementos de valor negativo
#
# 2) 1.	Crie uma função que recebe um número N que indicará quantos valores naturais devem ser lidos (digitados) em seguida, e guardados em uma lista. Após a leitura dos valores inteiros, o programa mostra uma tabela contendo cada valor lido e o fatorial desse valor.
#
# **DESAFIO**
#
# Fazer um programa em Python que receba os onze números do CPF em um string e transforme-o em uma lista, removendo os caracteres não numéricos (ponto, hífen, espaços, etc.). Em seguida, verificar se os dígitos verificadores (os dois últimos) são válidos.
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
